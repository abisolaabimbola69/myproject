# %% [markdown]
# <a href="https://colab.research.google.com/github/abisolaabimbola69/myproject/blob/main/Continuation_working_with_data_types_in_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data <- read.table("Mydata/Student.csv",header = TRUE,sep = ",")
#print(data)

print(data[1,])
# Out:
#   StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1      1001  17      1         0                 2        19.83372        7
#   Tutoring ParentalSupport Extracurricular Sports Music Volunteering      GPA
# 1        1               2               0      0     1            0 2.929196
#   GradeClass
# 1          2

# %%
class(data)
#print(data[,2])
# Out:
# [1] "data.frame"

# %%
data2 <- read.csv("Mydata/Student.csv")
data2
# Out:
#      StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1    1001      17  1      0         2                 19.833723        7
# 2    1002      18  0      0         1                 15.408756        0
# 3    1003      15  0      2         3                  4.210570       26
# 4    1004      17  1      0         3                 10.028829       14
# 5    1005      17  1      0         2                  4.672495       17
# 6    1006      18  0      0         1                  8.191219        0
# 7    1007      15  0      1         1                 15.601680       10
# 8    1008      15  1      1         4                 15.424496       22
# 9    1009      17  0      0         0                  4.562008        1
# 10   1010      16  1      0         1                 18.444466        0
# 11   1011      17  0      0         1                 11.851364       11
# 12   1012      17  0      0         1                  7.598486       15
# ...

# %%
data2 <- read.csv("Mydata/Student.csv")
data[,1]
# Out:
#    [1] 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014
#   [15] 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028
#   [29] 1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041 1042
#   [43] 1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055 1056
#   [57] 1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068 1069 1070
#   [71] 1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082 1083 1084
#   [85] 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096 1097 1098
#   [99] 1099 1100 1101 1102 1103 1104 1105 1106 1107 1108 1109 1110 1111 1112
#  [113] 1113 1114 1115 1116 1117 1118 1119 1120 1121 1122 1123 1124 1125 1126
#  [127] 1127 1128 1129 1130 1131 1132 1133 1134 1135 1136 1137 1138 1139 1140
#  [141] 1141 1142 1143 1144 1145 1146 1147 1148 1149 1150 1151 1152 1153 1154
#  [155] 1155 1156 1157 1158 1159 1160 1161 1162 1163 1164 1165 1166 1167 1168
# ...

# %% [markdown]
# # **To extract a column**

# %%
data2 <- read.csv("Mydata/Student.csv")
data[,2]
# Out:
#    [1] 17 18 15 17 17 18 15 15 17 16 17 17 17 17 18 15 18 18 18 17 16 15 16 18
#   [25] 18 16 16 16 18 18 15 15 18 16 16 15 18 15 15 17 17 17 16 18 18 18 18 17
#   [49] 16 16 17 16 17 18 17 18 18 15 17 15 17 17 15 15 17 16 18 15 18 16 16 16
#   [73] 15 16 15 16 18 18 17 18 17 18 15 18 17 17 16 15 18 16 18 18 16 16 16 16
#   [97] 16 18 16 15 17 16 16 18 16 16 16 18 16 17 18 17 18 16 17 18 15 16 18 15
#  [121] 18 15 16 17 15 18 16 15 18 18 18 15 15 15 17 15 15 15 17 15 18 15 18 18
#  [145] 18 17 17 17 15 18 17 17 15 17 15 16 17 16 15 18 17 15 18 18 16 15 18 17
#  [169] 17 16 18 15 17 18 18 16 17 17 15 17 15 17 16 17 15 15 16 17 17 16 17 17
#  [193] 15 17 17 16 16 18 15 17 17 18 17 15 18 15 18 18 16 15 17 17 15 17 17 15
#  [217] 18 15 18 17 17 17 16 18 16 16 15 16 15 15 16 18 18 18 18 18 16 16 17 18
#  [241] 16 17 18 15 17 16 15 15 15 17 16 15 18 15 15 17 17 16 18 17 15 16 15 15
#  [265] 17 16 18 18 17 17 16 18 18 18 15 18 15 16 15 16 18 18 16 17 16 17 15 15
# ...

# %% [markdown]
# # **Or use the dollar sign**

# %%
data2 <- read.csv("Mydata/Student.csv")
data2$age.head
# Out:
# NULL

# %%
data2 <- read.csv("Mydata/Student.csv")
print(data2)
# Out:
#      StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1         1001  17      1         0                 2    19.833722808        7
# 2         1002  18      0         0                 1    15.408756056        0
# 3         1003  15      0         2                 3     4.210569769       26
# 4         1004  17      1         0                 3    10.028829474       14
# 5         1005  17      1         0                 2     4.672495273       17
# 6         1006  18      0         0                 1     8.191218545        0
# 7         1007  15      0         1                 1    15.601680475       10
# 8         1008  15      1         1                 4    15.424496306       22
# 9         1009  17      0         0                 0     4.562007558        1
# 10        1010  16      1         0                 1    18.444466363        0
# 11        1011  17      0         0                 1    11.851363655       11
# ...

# %% [markdown]
# # **Using control statement**
# there are 2 types of control statement - the if(condition

# %%
data2 <- read.csv("Mydata/Student.csv")
d <- 20
if(d>18){
  print("This is greater")
}
# Out:
# [1] "This is greater"

# %% [markdown]
# # **Creating a new column**

# %%
data2 <- read.csv("Mydata/Student.csv")
data2$Remark <- "checked"
data2
# Out:
#      StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1    1001      17  1      0         2                 19.833723        7
# 2    1002      18  0      0         1                 15.408756        0
# 3    1003      15  0      2         3                  4.210570       26
# 4    1004      17  1      0         3                 10.028829       14
# 5    1005      17  1      0         2                  4.672495       17
# 6    1006      18  0      0         1                  8.191219        0
# 7    1007      15  0      1         1                 15.601680       10
# 8    1008      15  1      1         4                 15.424496       22
# 9    1009      17  0      0         0                  4.562008        1
# 10   1010      16  1      0         1                 18.444466        0
# 11   1011      17  0      0         1                 11.851364       11
# 12   1012      17  0      0         1                  7.598486       15
# ...

# %% [markdown]
# # **To multiply two columns**

# %%
data2 <- read.csv("Mydata/Student.csv")
data2$Support <- data2$ParentalEducation * data2$StudyTimeWeekly
data2
# Out:
#      StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1    1001      17  1      0         2                 19.833723        7
# 2    1002      18  0      0         1                 15.408756        0
# 3    1003      15  0      2         3                  4.210570       26
# 4    1004      17  1      0         3                 10.028829       14
# 5    1005      17  1      0         2                  4.672495       17
# 6    1006      18  0      0         1                  8.191219        0
# 7    1007      15  0      1         1                 15.601680       10
# 8    1008      15  1      1         4                 15.424496       22
# 9    1009      17  0      0         0                  4.562008        1
# 10   1010      16  1      0         1                 18.444466        0
# 11   1011      17  0      0         1                 11.851364       11
# 12   1012      17  0      0         1                  7.598486       15
# ...

# %% [markdown]
# # **Forming a column using the if else statement**

# %%
dd <- 20
if(dd<50){
  print("this is true")
}else{
  print("this is false")
}
# Out:
# [1] "this is true"

# %%
data3 <- read.csv("Mydata/Student.csv")
if(data3[2,1] > 20){
  print(data3[2,1])
  }else{
  print("There is no number greater than 20")
  }
# Out:
# [1] 1002

# %%
data4 <- read.csv("Mydata/Student.csv")
data4$Status <- ifelse(data4$GPA > 1.5, "Promoted", "Repeat")
data4
# Out:
#      StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1    1001      17  1      0         2                 19.833723        7
# 2    1002      18  0      0         1                 15.408756        0
# 3    1003      15  0      2         3                  4.210570       26
# 4    1004      17  1      0         3                 10.028829       14
# 5    1005      17  1      0         2                  4.672495       17
# 6    1006      18  0      0         1                  8.191219        0
# 7    1007      15  0      1         1                 15.601680       10
# 8    1008      15  1      1         4                 15.424496       22
# 9    1009      17  0      0         0                  4.562008        1
# 10   1010      16  1      0         1                 18.444466        0
# 11   1011      17  0      0         1                 11.851364       11
# 12   1012      17  0      0         1                  7.598486       15
# ...

# %% [markdown]
# # **Create a column that convert gender to male or female**

# %%
data5 <- read.csv("Mydata/Student.csv")
data5$Sex <- ifelse(data5$Gender>0, "FEMALE", "MALE")
data5
# Out:
#      StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1    1001      17  1      0         2                 19.833723        7
# 2    1002      18  0      0         1                 15.408756        0
# 3    1003      15  0      2         3                  4.210570       26
# 4    1004      17  1      0         3                 10.028829       14
# 5    1005      17  1      0         2                  4.672495       17
# 6    1006      18  0      0         1                  8.191219        0
# 7    1007      15  0      1         1                 15.601680       10
# 8    1008      15  1      1         4                 15.424496       22
# 9    1009      17  0      0         0                  4.562008        1
# 10   1010      16  1      0         1                 18.444466        0
# 11   1011      17  0      0         1                 11.851364       11
# 12   1012      17  0      0         1                  7.598486       15
# ...

# %% [markdown]
# # **To determine if they are teanager or adults**

# %%
data6 <- read.csv("Mydata/Student.csv")
data6$Age <- ifelse(data6$Age<18, "TEANAGER", "ADULT")
data6
# Out:
#      StudentID Age      Gender Ethnicity ParentalEducation StudyTimeWeekly
# 1    1001      TEANAGER 1      0         2                 19.833723
# 2    1002      ADULT    0      0         1                 15.408756
# 3    1003      TEANAGER 0      2         3                  4.210570
# 4    1004      TEANAGER 1      0         3                 10.028829
# 5    1005      TEANAGER 1      0         2                  4.672495
# 6    1006      ADULT    0      0         1                  8.191219
# 7    1007      TEANAGER 0      1         1                 15.601680
# 8    1008      TEANAGER 1      1         4                 15.424496
# 9    1009      TEANAGER 0      0         0                  4.562008
# 10   1010      TEANAGER 1      0         1                 18.444466
# 11   1011      TEANAGER 0      0         1                 11.851364
# 12   1012      TEANAGER 0      0         1                  7.598486
# 13   1013      TEANAGER 0      1         1                 10.038712
# ...

# %% [markdown]
# # ***To find mean age for teanager  and adult***

# %%
data7 <- read.csv("Mydata/Student.csv")
data7$demo <- ifelse(data7$Gender >= 18, "ADULT", "TEENS")
ouradult <- data7[data7$Age >= 18,]
ourteens <- data7[data7$Age < 18,]
mean(ouradult$Age)
mean(ourteens$Age)
# Out:
# [1] 18
# [1] 15.97624

# %% [markdown]
# # **Assignment - do the same for promoted and non promoted**

# %%
data8 <- read.csv("Mydata/Student.csv")
data8$demo <- ifelse(data8$GPA >= 1.5, "Promoted", "Repeat")
Promoted <- data8[data8$Status >= 1.5]
Repeat <- data8[data8$Status < 1.5]
mean(Promoted$Status)
mean(Repeat$Status)
data8
# Out:
# Warning message in mean.default(Promoted$Status):
# “argument is not numeric or logical: returning NA”
# [1] NA
# Warning message in mean.default(Repeat$Status):
# “argument is not numeric or logical: returning NA”
# [1] NA
#      StudentID Age Gender Ethnicity ParentalEducation StudyTimeWeekly Absences
# 1    1001      17  1      0         2                 19.833723        7
# 2    1002      18  0      0         1                 15.408756        0
# 3    1003      15  0      2         3                  4.210570       26
# 4    1004      17  1      0         3                 10.028829       14
# 5    1005      17  1      0         2                  4.672495       17
# 6    1006      18  0      0         1                  8.191219        0
# 7    1007      15  0      1         1                 15.601680       10
# 8    1008      15  1      1         4                 15.424496       22
# 9    1009      17  0      0         0                  4.562008        1
# ...

# %% [markdown]
# # **To get the datasets that are promoted**
