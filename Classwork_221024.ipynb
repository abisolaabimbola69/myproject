# %% [markdown]
# <a href="https://colab.research.google.com/github/abisolaabimbola69/myproject/blob/main/Classwork_221024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# classwork
# find the necessary features to predict crop yields and clean the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn import preprocessing

# %%
df = pd.read_excel("Mydata/worldfoodsupply.xls" )
df
# Out:
#       File Code  BLS Code   BLS Region BLS Region 2  Scenario Code  Scenario  \
# 0             1         9    Argentina    Argentina              1      GISS
# 1             1         9    Argentina    Argentina              2      GISS
# 2             1         9    Argentina    Argentina              3      GISS
# 3             1         9    Argentina    Argentina              4      GISS
# 4             1         9    Argentina    Argentina              5      GFDL
# ...         ...       ...          ...          ...            ...       ...
# 1083         32       156  New Zealand  New Zealand             42  CM2-S750
# 1084         32       156  New Zealand  New Zealand             43  CM2-S750
# 1085         32       156  New Zealand  New Zealand             44  CM2-S750
# 1086         32       156  New Zealand  New Zealand             45  CM2-S750
# 1087         32       156  New Zealand  New Zealand             46  CM2-S750
#
# ...

# %%
df.columns
# Out:
# Index(['File Code', 'BLS Code', 'BLS Region', 'BLS Region 2', 'Scenario Code',
#        'Scenario', 'Time_Slice', 'CO2 effects', 'CO2 ppm', 'Adapt- ation',
#        'wheat', 'rice', 'coarse grains', 'protein feed', 'Unnamed: 14',
#        'grains', 'four commo-dities'],
#       dtype='object')

# %%
categorical_data = ['BLS Region', 'CO2 ppm', 'Adapt- ation']
label_encoder = preprocessing.LabelEncoder()
for i in categorical_data:
    df[i] = label_encoder.fit_transform(df[i])

# df['BLS Region']
df['Adapt- ation']
# Out:
# 0       2
# 1       2
# 2       0
# 3       1
# 4       2
#        ..
# 1083    0
# 1084    0
# 1085    0
# 1086    0
# 1087    0
# Name: Adapt- ation, Length: 1088, dtype: int64

# %%
mycolumns = ['BLS Region', 'CO2 ppm', 'Adapt- ation',]
sns.pairplot(df[mycolumns])
plt.show()
